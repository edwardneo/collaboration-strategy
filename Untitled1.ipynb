# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array([
    [2, 0.019019, 0.999],
    [3, 0.186477, 0.917],
    # [3.05, 0.477745, 0.337],
    [3.1, 0.074115, 0.904],
    # [3.15, 0.66, 0.15],
    [3.2, 0.045267, 0.972],
    # [3.25, 2.137931, 0.029],
    [3.3, 0.042211, 0.995],
    # [3.35, 0.122034, 0.885],
    [3.4, 0.484848, 0.033],
    # [3.45, 4.454545, 0.011],
    [3.5, 4.777778, 0.0009],
    [4, 3.357143, 0.014],
    [5, 10, 0.0001],
    [10, 13, 0.0001]
])

# %%
plt.title("Percent Communication Response vs. Communication Cost")
plt.xlabel("Communication Cost")
plt.ylabel("Percent Communication Response")

plt.plot(data[:, 0], data[:, 2])

plt.savefig('pcr.jpg')

# %%
plt.title("Average Communication Time vs. Communication Cost")
plt.xlabel("Communication Cost")
plt.ylabel("Average Communication Time")

plt.plot(data[:, 0], data[:, 1])

plt.savefig('act.jpg')
